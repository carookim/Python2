# %%
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("tarekmasryo/youtube-shorts-and-tiktok-trends-2025")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Playdata2\.cache\kagglehub\datasets\tarekmasryo\youtube-shorts-and-tiktok-trends-2025\versions\2

# %%
df = pd.read_csv("C:/Users/Playdata2/.cache/kagglehub/datasets/tarekmasryo/youtube-shorts-and-tiktok-trends-2025/versions/2/youtube_shorts_tiktok_trends_2025.csv_ML.csv")
df.head()
# Out:
#   trend_label platform    region language category traffic_source  \
# 0      stable  youtube    Africa       es     Food         search
# 1      stable  youtube    Europe       it   Comedy           feed
# 2      stable   tiktok  Americas       en     Tech         search
# 3      rising   tiktok  Americas       ar   Comedy           feed
# 4      stable   tiktok  Americas       pt   Beauty         search
#
#   device_brand creator_tier  title_len  text_richness  ...  \
# 0      samsung         nano          2       1.999998  ...
# 1        apple        micro          2       1.999998  ...
# 2       google        micro          2       1.999998  ...
# 3       huawei          mid          2       1.999998  ...
# 4        apple         nano          2       1.999998  ...
#
#    share_hashtag_interaction  platform_cat  region_cat  language_cat  \
# 0                   0.056675             1           0             3
# 1                   0.092987             1           3             6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   trend_label                   50000 non-null  object
#  1   platform                      50000 non-null  object
#  2   region                        50000 non-null  object
#  3   language                      50000 non-null  object
#  4   category                      50000 non-null  object
#  5   traffic_source                50000 non-null  object
#  6   device_brand                  50000 non-null  object
#  7   creator_tier                  50000 non-null  object
#  8   title_len                     50000 non-null  int64
#  9   text_richness                 50000 non-null  float64
#  10  like_rate                     50000 non-null  float64
#  11  comment_rate                  50000 non-null  float64
# ...

# %%
# 결측치 여부
df.isnull().sum()
# Out:
# trend_label                     0
# platform                        0
# region                          0
# language                        0
# category                        0
# traffic_source                  0
# device_brand                    0
# creator_tier                    0
# title_len                       0
# text_richness                   0
# like_rate                       0
# comment_rate                    0
# share_rate                      0
# like_rate_log                   0
# comment_rate_log                0
# share_rate_log                  0
# views_per_day                   0
# likes_per_day                   0
# rel_like                        0
# rel_share                       0
# rel_combo                       0
# like_hashtag_interaction        0
# share_hashtag_interaction       0
# platform_cat                    0
# region_cat                      0
# language_cat                    0
# category_cat                    0
# ...

# %%
# 출력 제한 해제
# pd.set_option('display.max_rows', None)

# popularity 고유값별 개수 전부 보기
print(df['like_rate'].value_counts().sort_index())
# Out:
# like_rate
# 0.000000    15
# 0.000273     1
# 0.000291     1
# 0.000364     1
# 0.001193     1
# 0.001284     1
# 0.001730     1
# 0.001784     1
# 0.002047     1
# 0.002613     1
# 0.002812     1
# 0.003193     1
# 0.003220     1
# 0.003222     1
# 0.003608     1
# 0.003660     1
# 0.003805     1
# 0.004192     1
# 0.004206     1
# 0.004528     1
# 0.004602     1
# 0.004638     1
# 0.004827     1
# 0.004855     1
# 0.004885     1
# 0.005169     1
# 0.005213     1
# 0.005694     1
# 0.005728     1
# 0.006479     1
# 0.006596     1
# 0.006994     1
# 0.007030     1
# 0.007422     1
# 0.007546     1
# 0.007567     1
# 0.007819     1
# 0.007819     1
# 0.007949     1
# 0.008084     1
# 0.008178     1
# 0.008601     1
# 0.008700     1
# 0.008782     1
# 0.008784     1
# 0.008805     1
# 0.008898     1
# 0.008907     1
# 0.009022     1
# 0.009194     1
# 0.009200     1
# 0.009350     1
# 0.009654     1
# 0.009666     1
# 0.009777     1
# 0.009839     1
# 0.009853     1
# 0.009879     1
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df['like_rate'], bins=30)  # 30개 구간으로 나눔
plt.title('Distribution of like_rate')
plt.xlabel('like_rate')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()
